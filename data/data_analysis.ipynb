# %% [markdown]
# # Table of Contents
# 1. [Price Range Explanatory Data Analysis](#Price-Range-Explanatory-Data-Analysis)
#    1. [Setup & Imports](#Setup-&-Imports)
#    2. [Data Preparation](#Data-Preparation)
#    3. [Statistics](#Statistics)
#    4. [Duplicate Values](#Duplicate-Values)
#    5. [Missing Values](#Missing-Values)
#    6. [Outliers](#Outliers)
#    7. [Correlation](#Correlation)

# %% [markdown]
# # Price Range Explanatory Data Analysis

# %% [markdown]
# ## Setup & Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data_train = pd.read_csv('/home/data_train.csv')

data_validation = pd.read_csv('/home/data_validation.csv')

# %% [markdown]
# ## Data Preparation

# %%
df = data_train

# Reorder columns
df = df[[ 'battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi', 'price_range' ]]

# %%
# Change boolean/enum column value
df['blue']         = df['blue'].replace({ 0: 'No', 1: 'Yes' })
df['dual_sim']     = df['dual_sim'].replace({ 0: 'No', 1: 'Yes' })
df['four_g']       = df['four_g'].replace({ 0: 'No', 1: 'Yes' })
df['three_g']      = df['three_g'].replace({ 0: 'No', 1: 'Yes' })
df['touch_screen'] = df['touch_screen'].replace({ 0: 'No', 1: 'Yes' })
df['wifi']         = df['wifi'].replace({ 0: 'No', 1: 'Yes' })
df['price_range']  = df['price_range'].replace({ 0: 'Biaya Rendah', 1: 'Biaya Sedang', 2: 'Biaya Tinggi', 3: 'Biaya Sangat Tinggi' })

# Rename column for better readability
df = df.rename(columns={
  'battery_power' : 'Battery Power (mAh)',
  'clock_speed'   : 'Clock Speed (GHz)',
  'fc'            : 'Front Camera Resolution (MP)',
  'int_memory'    : 'Internal Memory (GB)',
  'm_dep'         : 'Thickness (cm)',
  'mobile_wt'     : 'Phone Weight (g)',
  'n_cores'       : 'Number of Cores',
  'pc'            : 'Main Camera Resolution (MP)',
  'px_height'     : 'Pixel Resolution Height',
  'px_width'      : 'Pixel Resolution Width',
  'ram'           : 'RAM (MB)',
  'sc_h'          : 'Screen Height (cm)',
  'sc_w'          : 'Screen Width (cm)',
  'talk_time'     : 'Maximum Call Time (h)',
  'blue'          : 'Bluetooth Support',
  'dual_sim'      : 'Dual Sim Support',
  'four_g'        : '4G Support',
  'three_g'       : '3G Support',
  'touch_screen'  : 'Touch Screen Support',
  'wifi'          : 'WiFi Support',
  'price_range'   : 'Price Range'
})

numerical_df = df[[ 'Battery Power (mAh)', 'Clock Speed (GHz)', 'Front Camera Resolution (MP)','Internal Memory (GB)','Thickness (cm)','Phone Weight (g)','Number of Cores','Main Camera Resolution (MP)','Pixel Resolution Height','Pixel Resolution Width','RAM (MB)','Screen Height (cm)','Screen Width (cm)','Maximum Call Time (h)' ]]

non_numerical_df = df[[ 'Bluetooth Support', 'Dual Sim Support', '4G Support', '3G Support', 'Touch Screen Support', 'WiFi Support', 'Price Range' ]]

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### Numerical Values Statistics

# %%
# Pulling columns with numerical values
numerical_data_df = numerical_df.describe().T

# Rename column for better readability
numerical_data_df = numerical_data_df.rename(columns={
    'count' : 'Count',
    'mean'  : 'Mean',
    'std'   : 'Standard Deviation',
    'min'   : 'Minimum Value',
    '25%'   : 'First Quartile',
    '50%'   : 'Second Quartile',
    '75%'   : 'Third Quartile',
    'max'   : 'Maximum Value'
})

numerical_data_df
# Out:
#                                Count         Mean  Standard Deviation  \
# Battery Power (mAh)           1400.0  1237.145714          430.051785
# Clock Speed (GHz)             1400.0     1.521714            0.814723
# Front Camera Resolution (MP)  1400.0     4.275000            4.324170
# Internal Memory (GB)          1400.0    31.962143           18.162970
# Thickness (cm)                1400.0     0.507857            0.288539
# Phone Weight (g)              1400.0   139.375714           35.400803
# Number of Cores               1400.0     4.481429            2.279836
# Main Camera Resolution (MP)   1400.0     9.917143            6.080023
# Pixel Resolution Height       1400.0   643.177857          444.628980
# Pixel Resolution Width        1400.0  1251.717143          428.982850
# RAM (MB)                      1400.0  2106.731429         1078.347277
# Screen Height (cm)            1400.0    12.285714            4.204198
# Screen Width (cm)             1400.0     5.665000            4.372234
# Maximum Call Time (h)         1400.0    11.042143            5.399052
#
#                               Minimum Value  First Quartile  Second Quartile  \
# Battery Power (mAh)                   501.0          864.75           1219.0
# Clock Speed (GHz)                       0.5            0.70              1.5
# Front Camera Resolution (MP)            0.0            1.00              3.0
# Internal Memory (GB)                    2.0           16.00             32.0
# Thickness (cm)                          0.1            0.20              0.5
# Phone Weight (g)                       80.0          108.00            139.0
# Number of Cores                         1.0            2.00              4.0
# Main Camera Resolution (MP)             0.0            5.00             10.0
# Pixel Resolution Height                 0.0          273.75            561.0
# Pixel Resolution Width                500.0          876.50           1247.0
# RAM (MB)                              256.0         1201.00           2102.0
# Screen Height (cm)                      5.0            9.00             12.0
# Screen Width (cm)                       0.0            2.00              5.0
# Maximum Call Time (h)                   2.0            6.00             11.0
#
#                               Third Quartile  Maximum Value
# Battery Power (mAh)                  1602.00         1998.0
# Clock Speed (GHz)                       2.20            3.0
# Front Camera Resolution (MP)            7.00           19.0
# Internal Memory (GB)                   48.00           64.0
# Thickness (cm)                          0.80            1.0
# Phone Weight (g)                      169.00          200.0
# Number of Cores                         7.00            8.0
# Main Camera Resolution (MP)            15.00           20.0
# Pixel Resolution Height               950.25         1960.0
# Pixel Resolution Width               1627.50         1998.0
# RAM (MB)                             3035.75         3998.0
# Screen Height (cm)                     16.00           19.0
# Screen Width (cm)                       9.00           18.0
# Maximum Call Time (h)                  16.00           20.0

# %% [markdown]
# #### Analysis
#
# From the data above, we can conclude the following:
# - Each cell in every column has a value
# - Clock Speed is likely measured in GHz
# - Phone Weight is likely measured in grams
# - Maximum Call Time is likely measured in hours

# %% [markdown]
# ### Non Numerical Values Statistics

# %%
non_numerical_data_df = non_numerical_df.describe().T

non_numerical_data_df = non_numerical_data_df.rename(columns={
    'count'   : 'Count',
    'unique'  : 'Distinct Values',
    'top'     : 'Largest Occurance',
    'freq'    : 'Amount of Occurance'
})

non_numerical_data_df
# Out:
#                      Count Distinct Values Largest Occurance  \
# Bluetooth Support     1400               2                No
# Dual Sim Support      1400               2               Yes
# 4G Support            1400               2               Yes
# 3G Support            1400               2               Yes
# Touch Screen Support  1400               2                No
# WiFi Support          1400               2                No
# Price Range           1400               4      Biaya Rendah
#
#                      Amount of Occurance
# Bluetooth Support                    709
# Dual Sim Support                     704
# 4G Support                           742
# 3G Support                          1065
# Touch Screen Support                 715
# WiFi Support                         707
# Price Range                          358

# %% [markdown]
# #### Analysis
#
# From the data above, we can conclude the following:
# - Support for Bluetooth, Dual Sim, Touch Screen, and WiFi is evenly distributed
# - There are slightly more phones that support 4G than those that don't
# - The majority of phones support 3G
# - The amount of data for a given price range is evenly distributed

# %% [markdown]
# ## Duplicate Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Battery Power (mAh), Clock Speed (GHz), Front Camera Resolution (MP), Internal Memory (GB), Thickness (cm), Phone Weight (g), Number of Cores, Main Camera Resolution (MP), Pixel Resolution Height, Pixel Resolution Width, RAM (MB), Screen Height (cm), Screen Width (cm), Maximum Call Time (h), Bluetooth Support, Dual Sim Support, 4G Support, 3G Support, Touch Screen Support, WiFi Support, Price Range]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Analysis
#
# There are no duplicated rows found

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# Battery Power (mAh)             0
# Clock Speed (GHz)               0
# Front Camera Resolution (MP)    0
# Internal Memory (GB)            0
# Thickness (cm)                  0
# Phone Weight (g)                0
# Number of Cores                 0
# Main Camera Resolution (MP)     0
# Pixel Resolution Height         0
# Pixel Resolution Width          0
# RAM (MB)                        0
# Screen Height (cm)              0
# Screen Width (cm)               0
# Maximum Call Time (h)           0
# Bluetooth Support               0
# Dual Sim Support                0
# 4G Support                      0
# 3G Support                      0
# Touch Screen Support            0
# WiFi Support                    0
# Price Range                     0
# dtype: int64

# %% [markdown]
# ### Analysis
#
# There are no missing values found

# %% [markdown]
# ## Outliers

# %%
# Finding outliers in each column with box plot

fig, ax = plt.subplots(7, 2, figsize=(15, 30))
df.boxplot('Battery Power (mAh)', ax=ax[0, 0])
df.boxplot('Clock Speed (GHz)', ax=ax[0, 1])
df.boxplot('Front Camera Resolution (MP)', ax=ax[1, 0])
df.boxplot('Internal Memory (GB)', ax=ax[1, 1])
df.boxplot('Thickness (cm)', ax=ax[2, 0])
df.boxplot('Phone Weight (g)', ax=ax[2, 1])
df.boxplot('Number of Cores', ax=ax[3, 0])
df.boxplot('Main Camera Resolution (MP)', ax=ax[3, 1])
df.boxplot('Pixel Resolution Height', ax=ax[4, 0])
df.boxplot('Pixel Resolution Width', ax=ax[4, 1])
df.boxplot('RAM (MB)', ax=ax[5, 0])
df.boxplot('Screen Height (cm)', ax=ax[5, 1])
df.boxplot('Screen Width (cm)', ax=ax[6, 0])
df.boxplot('Maximum Call Time (h)', ax=ax[6, 1])
# Out:
# <Axes: >

# %%
# Outliers in Front Camera Resolution column

front_camera_df = df['Front Camera Resolution (MP)']
q1, q3 = front_camera_df.quantile([0.25, 0.75])
maximum = q3 + 1.5 * (q3 - q1)

df[df['Front Camera Resolution (MP)'] > maximum ]
# Out:
#       Battery Power (mAh)  Clock Speed (GHz)  Front Camera Resolution (MP)  \
# 53                   1290                1.4                            19
# 98                   1731                2.3                            18
# 413                   946                2.6                            17
# 603                  1348                2.0                            18
# 778                  1533                1.1                            18
# 797                  1772                1.6                            17
# 1035                 1708                2.4                            18
# 1072                 1137                1.0                            18
# 1150                  695                0.5                            18
# 1232                 1957                1.2                            18
# 1342                 1937                1.7                            17
#
#       Internal Memory (GB)  Thickness (cm)  Phone Weight (g)  Number of Cores  \
# 53                      35             0.3               110                4
# 98                      60             0.5               171                4
# 413                      5             0.1               166                3
# 603                     52             0.3                98                3
# 778                     17             0.3               160                4
# 797                     45             0.5               159                2
# 1035                    49             0.1               109                1
# 1072                     7             1.0               196                3
# 1150                    12             0.6               196                2
# 1232                    36             0.8               151                2
# 1342                    58             0.6               189                1
#
#       Main Camera Resolution (MP)  Pixel Resolution Height  \
# 53                             20                      405
# 98                             20                      142
# 413                            20                     1698
# 603                            20                     1869
# 778                            20                     1054
# 797                            18                      837
# 1035                           19                      233
# 1072                           19                      942
# 1150                           19                     1649
# 1232                           19                     1194
# 1342                           19                     1728
#
#       Pixel Resolution Width  ...  Screen Height (cm)  Screen Width (cm)  \
# 53                       742  ...                  16                  2
# 98                      1039  ...                   9                  3
# 413                     1771  ...                  15                  7
# 603                     1942  ...                  18                 11
# 778                     1393  ...                   8                  2
# 797                     1405  ...                   6                  1
# 1035                     517  ...                   6                  4
# 1072                    1179  ...                  13                  5
# 1150                    1829  ...                  16                 13
# 1232                    1727  ...                  16                  2
# 1342                    1767  ...                   5                  4
#
#       Maximum Call Time (h)  Bluetooth Support Dual Sim Support 4G Support  \
# 53                        8                Yes              Yes        Yes
# 98                       20                Yes              Yes         No
# 413                       4                Yes              Yes         No
# 603                       7                 No               No         No
# 778                      11                Yes              Yes        Yes
# 797                      17                Yes               No        Yes
# 1035                     16                Yes              Yes        Yes
# 1072                     12                Yes               No         No
# 1150                      7                 No               No        Yes
# 1232                     18                 No              Yes        Yes
# 1342                     14                Yes               No         No
#
#      3G Support Touch Screen Support WiFi Support          Price Range
# 53          Yes                   No           No         Biaya Rendah
# 98           No                  Yes           No         Biaya Sedang
# 413          No                  Yes           No  Biaya Sangat Tinggi
# 603         Yes                  Yes          Yes         Biaya Sedang
# 778         Yes                   No          Yes         Biaya Tinggi
# 797         Yes                  Yes           No         Biaya Sedang
# 1035        Yes                  Yes          Yes  Biaya Sangat Tinggi
# 1072        Yes                  Yes          Yes  Biaya Sangat Tinggi
# 1150        Yes                  Yes          Yes         Biaya Tinggi
# 1232        Yes                   No          Yes         Biaya Sedang
# 1342        Yes                  Yes           No  Biaya Sangat Tinggi
#
# [11 rows x 21 columns]

# %% [markdown]
# ### Analysis
#
# It can be seen that there are 11 outlier data using the boxplot method.

# %% [markdown]
# ## Data Distribution

# %% [markdown]
# ### Numerical Values Plot

# %%
# Histogram for all numerical values

numerical_df.hist(sharex=False, sharey=False, figsize=(24, 24))
plt.show()

# %%
# Kurtosis

numerical_df.kurtosis()
# Out:
# Battery Power (mAh)            -1.168068
# Clock Speed (GHz)              -1.329523
# Front Camera Resolution (MP)    0.293404
# Internal Memory (GB)           -1.227200
# Thickness (cm)                 -1.266823
# Phone Weight (g)               -1.210202
# Number of Cores                -1.232209
# Main Camera Resolution (MP)    -1.163876
# Pixel Resolution Height        -0.316229
# Pixel Resolution Width         -1.176025
# RAM (MB)                       -1.186141
# Screen Height (cm)             -1.183273
# Screen Width (cm)              -0.334641
# Maximum Call Time (h)          -1.192018
# dtype: float64

# %% [markdown]
# ### Analysis
#
# Only Front Camera Resolution having a positive value of kurtosis, it means that there might be some extreme values (outliers) in the distribution. The rest of the column having a negative value of kurtosis, it means that the distribution are less likely to produce outliers.

# %% [markdown]
# ### Non Numerical Values

# %%
# Bar plot for all non numerical values

for column in non_numerical_df.columns:
  temp_df = non_numerical_df[column].value_counts()
  temp_df.plot(kind='bar', title=f'{column} histogram')
  plt.show()

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
# <ipython-input-114-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               Battery Power (mAh)  Clock Speed (GHz)  \
# Battery Power (mAh)                      1.000000           0.012937
# Clock Speed (GHz)                        0.012937           1.000000
# Front Camera Resolution (MP)             0.005774          -0.004902
# Internal Memory (GB)                     0.016187           0.005417
# Thickness (cm)                           0.017010          -0.023744
# Phone Weight (g)                         0.011705           0.008879
# Number of Cores                         -0.017015          -0.011135
# Main Camera Resolution (MP)              0.003270          -0.003518
# Pixel Resolution Height                 -0.003244          -0.016482
# Pixel Resolution Width                  -0.019042           0.012462
# RAM (MB)                                -0.013218           0.022962
# Screen Height (cm)                      -0.022521           0.004114
# Screen Width (cm)                       -0.022134           0.020765
# Maximum Call Time (h)                    0.038071          -0.000566
#
#                               Front Camera Resolution (MP)  \
# Battery Power (mAh)                               0.005774
# Clock Speed (GHz)                                -0.004902
# Front Camera Resolution (MP)                      1.000000
# Internal Memory (GB)                             -0.041477
# Thickness (cm)                                   -0.017144
# Phone Weight (g)                                  0.027141
# Number of Cores                                  -0.006261
# Main Camera Resolution (MP)                       0.644348
# Pixel Resolution Height                          -0.016191
# Pixel Resolution Width                           -0.050449
# RAM (MB)                                          0.001307
# Screen Height (cm)                               -0.010459
# Screen Width (cm)                                -0.008810
# Maximum Call Time (h)                             0.003483
#
#                               Internal Memory (GB)  Thickness (cm)  \
# Battery Power (mAh)                       0.016187        0.017010
# Clock Speed (GHz)                         0.005417       -0.023744
# Front Camera Resolution (MP)             -0.041477       -0.017144
# Internal Memory (GB)                      1.000000        0.041084
# Thickness (cm)                            0.041084        1.000000
# Phone Weight (g)                         -0.040759        0.053034
# Number of Cores                          -0.041109       -0.020967
# Main Camera Resolution (MP)              -0.031596        0.019481
# Pixel Resolution Height                   0.026845        0.008807
# Pixel Resolution Width                   -0.003778       -0.023390
# RAM (MB)                                  0.007183       -0.006886
# Screen Height (cm)                        0.024976       -0.021827
# Screen Width (cm)                        -0.005848       -0.023862
# Maximum Call Time (h)                    -0.028856        0.016902
#
#                               Phone Weight (g)  Number of Cores  \
# Battery Power (mAh)                   0.011705        -0.017015
# Clock Speed (GHz)                     0.008879        -0.011135
# Front Camera Resolution (MP)          0.027141        -0.006261
# Internal Memory (GB)                 -0.040759        -0.041109
# Thickness (cm)                        0.053034        -0.020967
# Phone Weight (g)                      1.000000        -0.006866
# Number of Cores                      -0.006866         1.000000
# Main Camera Resolution (MP)           0.003947         0.004117
# Pixel Resolution Height              -0.009501         0.006308
# Pixel Resolution Width               -0.026278         0.025477
# RAM (MB)                             -0.046080         0.007089
# Screen Height (cm)                   -0.072128        -0.005188
# Screen Width (cm)                    -0.026295         0.007084
# Maximum Call Time (h)                -0.014507         0.050324
#
#                               Main Camera Resolution (MP)  \
# Battery Power (mAh)                              0.003270
# Clock Speed (GHz)                               -0.003518
# Front Camera Resolution (MP)                     0.644348
# Internal Memory (GB)                            -0.031596
# Thickness (cm)                                   0.019481
# Phone Weight (g)                                 0.003947
# Number of Cores                                  0.004117
# Main Camera Resolution (MP)                      1.000000
# Pixel Resolution Height                         -0.014816
# Pixel Resolution Width                          -0.041898
# RAM (MB)                                         0.000169
# Screen Height (cm)                               0.002968
# Screen Width (cm)                               -0.034817
# Maximum Call Time (h)                            0.002349
#
#                               Pixel Resolution Height  Pixel Resolution Width  \
# Battery Power (mAh)                         -0.003244               -0.019042
# Clock Speed (GHz)                           -0.016482                0.012462
# Front Camera Resolution (MP)                -0.016191               -0.050449
# Internal Memory (GB)                         0.026845               -0.003778
# Thickness (cm)                               0.008807               -0.023390
# Phone Weight (g)                            -0.009501               -0.026278
# Number of Cores                              0.006308                0.025477
# Main Camera Resolution (MP)                 -0.014816               -0.041898
# Pixel Resolution Height                      1.000000                0.507443
# Pixel Resolution Width                       0.507443                1.000000
# RAM (MB)                                    -0.008768                0.023148
# Screen Height (cm)                           0.053254                0.026920
# Screen Width (cm)                            0.019898                0.039929
# Maximum Call Time (h)                        0.009717                0.008690
#
#                               RAM (MB)  Screen Height (cm)  Screen Width (cm)  \
# Battery Power (mAh)          -0.013218           -0.022521          -0.022134
# Clock Speed (GHz)             0.022962            0.004114           0.020765
# Front Camera Resolution (MP)  0.001307           -0.010459          -0.008810
# Internal Memory (GB)          0.007183            0.024976          -0.005848
# Thickness (cm)               -0.006886           -0.021827          -0.023862
# Phone Weight (g)             -0.046080           -0.072128          -0.026295
# Number of Cores               0.007089           -0.005188           0.007084
# Main Camera Resolution (MP)   0.000169            0.002968          -0.034817
# Pixel Resolution Height      -0.008768            0.053254           0.019898
# Pixel Resolution Width        0.023148            0.026920           0.039929
# RAM (MB)                      1.000000           -0.000824           0.021422
# Screen Height (cm)           -0.000824            1.000000           0.493816
# Screen Width (cm)             0.021422            0.493816           1.000000
# Maximum Call Time (h)         0.005407           -0.028085          -0.029864
#
#                               Maximum Call Time (h)
# Battery Power (mAh)                        0.038071
# Clock Speed (GHz)                         -0.000566
# Front Camera Resolution (MP)               0.003483
# Internal Memory (GB)                      -0.028856
# Thickness (cm)                             0.016902
# Phone Weight (g)                          -0.014507
# Number of Cores                            0.050324
# Main Camera Resolution (MP)                0.002349
# Pixel Resolution Height                    0.009717
# Pixel Resolution Width                     0.008690
# RAM (MB)                                   0.005407
# Screen Height (cm)                        -0.028085
# Screen Width (cm)                         -0.029864
# Maximum Call Time (h)                      1.000000

# %%
# Correlation graph

temp_df = data_train

corr = temp_df.corr().price_range.sort_values(ascending = False)[1:]
sns.barplot(x = corr, y = corr.index)
plt.title("Correlation between price range and other features")
# Out:
# Text(0.5, 1.0, 'Correlation between price range and other features')

# %% [markdown]
# ### Analysis
#
# From the graph above, we can conclude that phone price are largely influenced by the amount of RAM it has.
